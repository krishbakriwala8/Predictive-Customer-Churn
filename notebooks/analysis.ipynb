# %% [markdown]
# # Predictive Customer Churn — Analysis Notebook
#
# This notebook provides exploratory data analysis, model summaries, and visualizations for the churn project. The full pipeline is available in `churn_project.py` (run that script to reproduce features, models, and Power BI outputs).

# %%
# Example: run the pipeline from this notebook (it will download the dataset automatically if not present)
# !python churn_project.py --out outputs --future-window-days 180

# %% [markdown]
# After running the script, inspect `outputs/model_report.txt`, `outputs/powerbi_aggregates.csv`, and `outputs/features_for_model.csv`.
# Add visualizations here (RFM heatmap, churn distribution, feature importances).
